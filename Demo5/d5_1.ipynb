# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
e1 = pd.read_excel("问题五.xlsx")
e2 = pd.read_excel('植物量-放牧强度.xlsx')

# %%
def zzt(data):
    plt.rcParams['font.sans-serif'] = ['SimHei']  # 黑体
    plt.rcParams['axes.unicode_minus'] = False    # 解决无法显示符号的问题
    sns.set(font='SimHei', font_scale=1)        # 解决Seaborn中文显示问题
    plt.subplots(figsize=(6,4),dpi=1080,facecolor='w')# 设置画布大小，分辨率，和底色

    x = data['放牧策略']
    x_width = range(0,len(x))
    x2_width = [i+0.15 for i in x_width]
    x3_width = [i+0.3 for i in x_width]
    x4_width = [i+0.45 for i in x_width]

    data_0 = data.iloc[:,1]
    data_1 = data.iloc[:,1]
    data_2 = data.iloc[:,3]
    data_3 = data.iloc[:,4]

    plt.bar(x_width,data_0,width = 0.15, color="w",edgecolor="k",hatch="///",label = '牧前')
    plt.bar(x2_width,data_1,width = 0.15,color="w",edgecolor="k",hatch="xxx",label = '第一轮牧后')
    plt.bar(x3_width,data_2,width = 0.15,color="gray",edgecolor="k",label = '第二轮牧后')
    plt.bar(x4_width,data_3,width = 0.15,color="black",edgecolor="k",label = '第三轮牧后')

    plt.legend(loc=2)
    plt.xticks(range(0,4),x)

zzt(e2)
